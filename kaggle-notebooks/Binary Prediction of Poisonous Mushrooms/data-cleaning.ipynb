# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('data/train.csv')
train.shape
# Out:
# (3116945, 22)

# %%
train.head()
# Out:
#    id class  cap-diameter cap-shape cap-surface cap-color  \
# 0   0     e          8.80         f           s         u
# 1   1     p          4.51         x           h         o
# 2   2     e          6.94         f           s         b
# 3   3     e          3.88         f           y         g
# 4   4     e          5.85         x           l         w
#
#   does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                    f               a            c          w  ...
# 1                    f               a            c          n  ...
# 2                    f               x            c          w  ...
# 3                    f               s          NaN          g  ...
# 4                    f               d          NaN          w  ...
#
#    stem-root  stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0        NaN           NaN          w       NaN        NaN        f         f
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3116945 entries, 0 to 3116944
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   class                 object
#  2   cap-diameter          float64
#  3   cap-shape             object
#  4   cap-surface           object
#  5   cap-color             object
#  6   does-bruise-or-bleed  object
#  7   gill-attachment       object
#  8   gill-spacing          object
#  9   gill-color            object
#  10  stem-height           float64
#  11  stem-width            float64
#  12  stem-root             object
#  13  stem-surface          object
#  14  stem-color            object
#  15  veil-type             object
#  16  veil-color            object
#  17  has-ring              object
#  18  ring-type             object
#  19  spore-print-color     object
#  20  habitat               object
#  21  season                object
# ...

# %%
pd.DataFrame({
    "colum-name" : train.columns,
    "null-count": train.isna().sum().values,
    "% null-count": np.round(train.isna().sum().values * 100 / len(train), 5)
}).sort_values(by="null-count", ascending=False).reset_index(drop=True)
# Out:
#               colum-name  null-count  % null-count
# 0              veil-type     2957493      94.88435
# 1      spore-print-color     2849682      91.42548
# 2              stem-root     2757023      88.45273
# 3             veil-color     2740947      87.93697
# 4           stem-surface     1980861      63.55136
# 5           gill-spacing     1258435      40.37399
# 6            cap-surface      671023      21.52823
# 7        gill-attachment      523936      16.80928
# 8              ring-type      128880       4.13482
# 9             gill-color          57       0.00183
# 10               habitat          45       0.00144
# 11             cap-shape          40       0.00128
# 12            stem-color          38       0.00122
# 13              has-ring          24       0.00077
# 14             cap-color          12       0.00038
# 15  does-bruise-or-bleed           8       0.00026
# 16          cap-diameter           4       0.00013
# ...

# %%
target = "class"
categorical_columns = train.select_dtypes(include='object').columns.drop(target)
numerical_columns = train.select_dtypes(exclude='object').columns
print("categorical_columns: ", categorical_columns)
print("numerical_columns: ", numerical_columns)
# Out:
# categorical_columns:  Index(['cap-shape', 'cap-surface', 'cap-color', 'does-bruise-or-bleed',
#        'gill-attachment', 'gill-spacing', 'gill-color', 'stem-root',
#        'stem-surface', 'stem-color', 'veil-type', 'veil-color', 'has-ring',
#        'ring-type', 'spore-print-color', 'habitat', 'season'],
#       dtype='object')
# numerical_columns:  Index(['id', 'cap-diameter', 'stem-height', 'stem-width'], dtype='object')

# %%
for col in categorical_columns:
    value_counts = train[col].value_counts().head(10)
    print(f"\nTop values counts in '{col}':  \n{value_counts}")
# Out:
# Top values counts in 'cap-shape':
# x    1436026
# f     676238
# s     365146
# b     318646
# o     108835
# p     106967
# c     104520
# d         65
# e         60
# n         41
# Name: cap-shape, dtype: int64
#
# Top values counts in 'cap-surface':
# t    460777
# s    384970
# y    327826
# h    284460
# g    263729
# d    206832
# k    128875
# e    119712
# i    113440
# w    109840
# Name: cap-surface, dtype: int64
#
# Top values counts in 'cap-color':
# n    1359542
# y     386627
# w     379442
# g     210825
# e     197290
# o     178847
# p      91838
# r      78236
# u      73172
# b      61313
# Name: cap-color, dtype: int64
#
# Top values counts in 'does-bruise-or-bleed':
# f    2569743
# t     547085
# w         14
# c         11
# h          9
# a          7
# b          7
# x          7
# y          7
# k          6
# Name: does-bruise-or-bleed, dtype: int64
#
# Top values counts in 'gill-attachment':
# a    646034
# d    589236
# x    360878
# e    301858
# ...
